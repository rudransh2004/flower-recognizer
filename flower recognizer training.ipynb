# %%
# !pip install -q kaggle

# %%
# !ls
# Out:
# kaggle.json  sample_data

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
root_path = 'gdrive/My Drive/kaggle/'

# %%
# !kaggle datasets download -d alxmamaev/flowers-recognition -p /content/gdrive/My\ Drive/kaggle/flowers
# Out:
# ...
#  99% 446M/450M [00:03<00:00, 140MB/s]
# 100% 450M/450M [00:03<00:00, 123MB/s]

# %%
! mkdir train

# %%
! unzip flowers-recognition.zip -d train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/flowers/flowers/rose/11102341464_508d558dfc_n.jpg
#   inflating: train/flowers/flowers/rose/11233672494_d8bf0a3dbf_n.jpg
#   inflating: train/flowers/flowers/rose/11694025703_9a906fedc1_n.jpg
#   inflating: train/flowers/flowers/rose/118974357_0faa23cce9_n.jpg
#   inflating: train/flowers/flowers/rose/11944957684_2cc806276e.jpg
#   inflating: train/flowers/flowers/rose/12165480946_c4a3fe182d_n.jpg
#   inflating: train/flowers/flowers/rose/12202373204_34fb07205b.jpg
#   inflating: train/flowers/flowers/rose/12238827553_cf427bfd51_n.jpg
#   inflating: train/flowers/flowers/rose/12240165555_98625b1e88_n.jpg
#   inflating: train/flowers/flowers/rose/12240303_80d87f77a3_n.jpg
#   inflating: train/flowers/flowers/rose/12240577184_b0de0e53ea_n.jpg
#   inflating: train/flowers/flowers/rose/12243068283_ee4c2683e2_n.jpg
#   inflating: train/flowers/flowers/rose/12243069253_e512464095_n.jpg
# ...

# %%
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-2.2.0rc2:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0rc2.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0rc2

# %%
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 93kB/s
# ...
#      |████████████████████████████████| 3.2MB 41.1MB/s
# ...
#      |████████████████████████████████| 491kB 52.8MB/s
# ...
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
# ...

# %%
import os
daisy_path  = "/content/train/flowers/daisy/"
dandelion_path = "/content/train/flowers/dandelion/"
rose_path = "/content/train/flowers/rose/"
sunflower_path = "/content/train/flowers/sunflower/"
tulip_path = "/content/train/flowers/tulip/"

# %%
from os import listdir
import cv2

train_data = []
labels = []
size = 128,128

def in_images(images,directory,size,label):
  try:
    for i in range(len(images)):
      img = cv2.imread(directory+images[i])
      img = cv2.resize(img,size)
      train_data.append(img)
      labels.append(label)

  except:
    pass

in_images(listdir(daisy_path),daisy_path,size,0)
in_images(listdir(dandelion_path),dandelion_path,size,1)
in_images(listdir(rose_path),rose_path,size,2)
in_images(listdir(sunflower_path),sunflower_path,size,3)
in_images(listdir(tulip_path),tulip_path,size,4)

# %%
len(train_data),len(labels)
# Out:
# (3550, 3550)

# %%
import numpy as np 

data = np.asarray(train_data)
data = data/255.0

labels = np.asarray(labels)

# %%
data.shape , labels.shape
# Out:
# ((3550, 128, 128, 3), (3550,))

# %%
# !pip install sklearn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.20, shuffle= True)

# %%
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense

model = Sequential()
model.add(Conv2D(16, (2,2),input_shape=(128, 128, 3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(32, (2,2),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

batch_size = 128
epochs = 30
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("flower_recognizer.h5")
print("Saved model to disk")

# %%
from google.colab import files
files.download("model.json")

# %%
pred = []
size = 128,128
def conversion(img):
  
  im = cv2.imread(img)
  im = cv2.resize(im,size)
  pred.append(im)
  data = np.asarray(pred)
  data = data/255.0
  return data

def prediciton(path):
  ar = conversion(path)
  score = model.predict(ar)
  a = np.argmax(score)
  if a  ==[0]:
    return "daisy"
  if a ==[1]:
    return "dandelion" 
  if a ==[2]:
    return "rose"
  if a ==[3]:
    return "sunflower"
  if a == [4]:
    return "tulip"       

  

prediciton("/content/download (4).jpg")
# Out:
# 'dandelion'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cdb33cc9-741c-4ed9-8f8b-bde38ebfec90" name="files[]" multiple disabled />
#      <output id="result-cdb33cc9-741c-4ed9-8f8b-bde38ebfec90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download (4).jpg to download (4).jpg
# ...
